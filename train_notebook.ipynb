# %%
import train

# %%
config = {'batchsize':1, 'lr':1e-4, 'wd':1e-5, 'epochs':800, 'logdir':'./log/Jan14_TFR5', 'saveTensorInterval':50,
         'saveModelInterval':20, 'restore':'./log/Jan14_TFR5', 'outdir':'./outJan14_TFR5', 'train':True}

# %%
train.main(config)
# Out:
# Loading weights from ./log/Jan14_TFR5
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /d2/studies/TF2DeepFloorplan/train.py:95: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan14_TFR5/0/47465963_bounds.png is a low contrast image
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_bounds.png'), b)
# /d2/studies/TF2DeepFloorplan/train.py:97: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan14_TFR5/0/47465963_doors_windows.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_doors_windows.png'), ents)
# /d2/studies/TF2DeepFloorplan/train.py:97: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan14_TFR5/0/47465963_doors_windows.png is a low contrast image
# ...
