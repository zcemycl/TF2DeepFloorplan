# %%
import train

# %%
config = {'batchsize':1, 'lr':5e-5, 'wd':1e-5, 'epochs':200, 'logdir':'./log/Jan14_TFR5', 'saveTensorInterval':10,
         'saveModelInterval':20, 'restore':None, 'outdir':'./outJan14_TFR5', 'train':True}

# %%
train.main(config)
# Out:
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /d2/studies/TF2DeepFloorplan/train.py:98: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan14_TFR3_5/0/31887483_rooms.png is a low contrast image
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_rooms.png'), r.astype(np.uint8))
# Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# /d2/studies/TF2DeepFloorplan/train.py:102: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan14_TFR3_5/0/31887483_rooms_pred.png is a low contrast image
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_rooms_pred.png'), lr)
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
