# %%
import tensorboard

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir='./log/Jan14_TFR5'
# Out:
#       <iframe id="tensorboard-frame-d2fea4334d710ef5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d2fea4334d710ef5");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
