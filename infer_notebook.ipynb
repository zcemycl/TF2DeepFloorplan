# %%
import infer

# %%
config = {'batchsize':1, 'lr':1e-4, 'logdir':'./log/Jan15_TFR5_TEST', 'checkpoint':'./log/Jan14_TFR5', 
          'outdir':'./outJan15_TFR5_TEST', 'train':False}

# %%
infer.infer(config)
# Out:
# Loading weights from ./log/Jan14_TFR5
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0.0, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# /d2/studies/TF2DeepFloorplan/infer.py:105: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan15_TFR5_TEST/0/47545148_doors_windows.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_doors_windows.png'), ents)
# /d2/studies/TF2DeepFloorplan/infer.py:107: UserWarning: /d2/studies/TF2DeepFloorplan/./outJan15_TFR5_TEST/0/47545148_rooms_pred.png is a low contrast image
#   imsave(os.path.join(os.getcwd(), outdir + '/' + str(pltiter) + '/' + name + '_rooms_pred.png'), lr)
# ...
